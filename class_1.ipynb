# %% [markdown]
# <a href="https://colab.research.google.com/github/Sowrove-Khan/Python_Programming/blob/main/class_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#load library
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
#load dataset
df = pd.read_csv('pizza_price.csv')
print(df)
# Out:
#    Inch   Taka
# 0     S  12.75
# 1     M  16.75
# 2     L  20.75
# 3     S  12.75
# 4     M  16.75
# ..  ...    ...
# 91    M  16.00
# 92    L  20.25
# 93    S  12.00
# 94    M  16.00
# 95    L  20.25
#
# [96 rows x 2 columns]

# %%
df.head(3)
# Out:
#   Inch   Taka
# 0    S  12.75
# 1    M  16.75
# 2    L  20.75

# %%
plt.xlabel('Pizza Size in Inch')
plt.ylabel('Pizza Price in Taka')
plt.scatter(df['Inch'], df['Taka'], marker='+', color = 'red')
plt.plot(df.Inch, reg.predict(df[['Inch']]), color='blue')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-ea4ded65a1bf> in <cell line: 4>()
#       2 plt.ylabel('Pizza Price in Taka')
#       3 plt.scatter(df['Inch'], df['Taka'], marker='+', color = 'red')
# ----> 4 plt.plot(df.Inch, reg.predict(df[['Inch']]), color='blue')
#
# NameError: name 'reg' is not defined

# %%
x = df[['Inch']]
y = df['Taka']
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3)

# %%
xtrain
# Out:
#    Inch
# 1     8
# 3    14
# 2    12

# %%
xtest
# Out:
#    Inch
# 2     L
# 77    L
# 88    M
# 21    S
# 43  XXL
# 29    L
# 78    S
# 63    S
# 39    S
# 62    L
# 93    S
# 0     S
# 48    S
# 23    L
# 10    M
# 59    L
# 70    M
# 45    S
# 89    L
# 9     S
# 83    L
# 60    S
# 80    L
# 57    S
# 50    L
# 91    M
# 24    S
# 51    S
# 1     M

# %%
ytrain
# Out:
# 72    11.75
# 53    20.75
# 90    12.00
# 86    20.25
# 84    12.00
#       ...
# 25    13.25
# 3     12.75
# 37    12.50
# 73    14.75
# 66    12.50
# Name: Taka, Length: 67, dtype: float64

# %%
ytest
# Out:
# 0     350
# 4    1675
# Name: Taka, dtype: int64

# %%
#create regression object
reg = LinearRegression()
reg.fit(xtrain, ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-91aeca69f903> in <cell line: 3>()
#       1 #create regression object
#       2 reg = LinearRegression()
# ----> 3 reg.fit(xtrain, ytrain)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
reg.score(xtest, ytest)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-44e653e1894e> in <cell line: 1>()
# ----> 1 reg.score(xtest, ytest)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     720         from .metrics import r2_score
#     721
# --> 722         y_pred = self.predict(X)
#     723         return r2_score(y, y_pred, sample_weight=sample_weight)
#     724
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     352             Returns predicted values.
#     353         """
# --> 354         return self._decision_function(X)
#     355
#     356     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     335         check_is_fitted(self)
#     336
# ...

# %%
n = input('Enter any Inch: ')
array = np.array(n)
array2 = array.astype(float)
value = np.array([[array2]])

result = reg.predict(value)

pizza_price = np.array(result)
pizza_price = pizza_price.item()

print("Predicted Pizza Price: ", pizza_price)
# Out:
# Enter any Inch:  17
# Predicted Pizza Price:  1615.5263157894738
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
